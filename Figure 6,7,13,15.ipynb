# %%
import numpy as np
import matplotlib.pylab as plt
plt.rc('font',family='Times New Roman')
fig = plt.figure()
# fig.set_size_inches(12,6)


U9 = np.loadtxt('UM/9cy/U_300s.xy',skiprows=4)
U13 = np.loadtxt('UM/13cy/line.xy',skiprows=4)
U17 = np.loadtxt('UM/17cy/line.xy',skiprows=4)
U21= np.loadtxt('UM/21cy/U_300s.xy',skiprows=4)
U24= np.loadtxt('UM/24cy/U_300s.xy',skiprows=4)
U24p= np.loadtxt('UM/24cy/U_500s.xy',skiprows=4)

Up= np.loadtxt('UM/porousCy/line.xy',skiprows=4)
Umt= np.loadtxt('UM/multicy/line_1.xy',skiprows=4)

v1 = (U9[:,0]-100)/10.8
v2 = (U13[:,0]-100)/10.8
v3 = (U17[:,0]-100)/10.8
v4 = (U21[:,0]-100)/10.8
v5 = (U24[:,0]-100)/10.8
v6 = (U24p[:,0]-100)/10.8

v7 = (Umt[:,0]-100)/10.8
vp = (Up[:,0]-100)/10.8

# plt.plot(v1,U9[:,1],linestyle='-',c='b',label='inP')
# plt.plot(v2,U13[:,1],linestyle='-',c='r',label='inP')
# plt.plot(v3,U17[:,1],linestyle='-',c='k',label='inP')
# plt.plot(v4,U21[:,1],linestyle='-',c='g',label='inP')
# plt.plot(v5,U24[:,1],linestyle='-',c='y',label='inP')
# plt.plot(v6,U24p[:,1],linestyle='-',c='r',label='inP')

# plt.plot(vp,Up[:,1],linestyle='-',c='k',label='inP')
# plt.scatter(v7,Umt[:,1],marker='+',c='k',label='inP')

#############################################################
# SVF=0.2
UmtNew = np.loadtxt('UM/multicy/graphUniform/300/line_1.xy')
vNew = (UmtNew[:,0]-100)/10.8
# plt.scatter(vNew,UmtNew[:,1],marker='+',c='k',label='Presnet work')

Uchang = np.loadtxt('UM/Chang,2021,SVF=0.2(2D).csv')
uChangV = Uchang[:,0]
# plt.scatter(uChangV,Uchang[:,1])

Uchang2 = np.loadtxt('UM/Chang,2021,SVF=0.1.csv')
uChangV2 = Uchang2[:,0]
plt.scatter(uChangV2,Uchang2[:,1],label='Chang(2015)',c='r')

##########################################################
# SVF=0.023
# U9 = np.loadtxt('UM/9cy/U_300s.xy',skiprows=4)
# v1 = (U9[:,0]-100)/10.8

# plt.scatter(v1,U9[:,1],marker='+',c='k',label='Present work')

# Uchang3 = np.loadtxt('UM/Chang,2021,SVF=0.023.csv')
# uChangV3 = Uchang3[:,0]
# plt.scatter(uChangV3,Uchang3[:,1],label='Chang(2015)',c='r')
# ##############################################################
# SVF=0.15
# plt.scatter(v3,U17[:,1],marker='+',c='k',label='Presnet work')
# # plt.scatter(v1,U9[:,1],marker='+',c='k',label='Present work')

# Uchang4 = np.loadtxt('UM/Chang,2015,SVF=0.05.csv')
# uChangV4 = Uchang4[:,0]+0.5
# plt.scatter(uChangV4,Uchang4[:,1],label='Chang(2015)',c='r')
# ##############################################################

plt.xlim([-5,9.5])
plt.ylim([-0.4,1.2])

#####################################
plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
axes.minorticks_on()
# plt.tick_params(which='major',width=2)
plt.tick_params(which='major',length=6)
# plt.tick_params(which='minor',width=2)
# plt.tick_params(which='minor',length=3)
#####################################
# plt.grid(linestyle='--')
plt.legend(fontsize=16)
plt.xlabel('Distance(x/D)',fontsize=16)
plt.ylabel('Relative Velocity(u / U$_{IN}$)',fontsize=16)

text = 'SVF=0.15'
plt.text(6,0,text,size=16, style = "italic",weight="light")

x = [-0.5,-0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')
x = [0.5,0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')

# plt.scatter((min[:,0]-100)/10.8,min[:,1],marker='+',c='k',label='0.39 million')
# plt.scatter((mid[:,0]-100)/10.8,mid[:,1],marker='o',c='none',edgecolors='b',label='1.42 million')
# plt.scatter((max[:,0]-100)/10.8,max[:,1],marker='^',c='none',edgecolors='r',label='2.74 million')

# %%
U21new = np.loadtxt('results/velocity//mid/21.xy',skiprows=4)
v4new = (U21new[:,0]-100)/10.8
#Ux and Uy varies with distance
plt.rc('font',family='Times New Roman')
fig = plt.figure()

# plt.scatter(v1,U9[:,1],linestyle='-',c='none',label='SVF1',marker='v',edgecolors='k')
# plt.scatter(v2,U13[:,1],linestyle='-',c='b',label='SVF2',marker='+')
# plt.scatter(v3,U17[:,1],linestyle='-',c='none',label='SVF3',marker='s',edgecolors='g')
# plt.scatter(v4new,U21[:,1],linestyle='-',c='m',label='SVF4',marker='.')
# plt.scatter(v5,U24[:,1],linestyle='-',c='none',label='SVF5',marker='o',edgecolors='r')

plt.plot(v1,U9[:,1],linestyle='--',c='k',label='SVF1')
plt.plot(v2,U13[:,1],linestyle='--',c='b',label='SVF2')
plt.plot(v3,U17[:,1],linestyle='--',c='g',label='SVF3')
plt.plot(v4new,U21[:,1],linestyle='--',c='m',label='SVF4')
plt.plot(v5,U24[:,1],linestyle='--',c='r',label='SVF5')
# plt.plot(v6,U24p[:,1],linestyle='-',c='r',label='SVF5')

# plt.scatter(uChangV2,Uchang2[:,1],label='Chang(2015)',c='r')

plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
axes.minorticks_on()
plt.tick_params(which='major',length=6)
plt.legend(fontsize=14)
plt.xlabel('Distance(x/D)',fontsize=16)
plt.ylabel('Relative Velocity(u / U$_{IN}$)',fontsize=16)

plt.xlim([-5,9])
plt.ylim([-0.4,1.2])

# canopy line 
x = [-0.5,-0.5]
y = [-2,3]
plt.plot(x,y,linestyle = '--',c='g')
x = [0.5,0.5]
y = [-2,3]
plt.plot(x,y,linestyle = '--',c='g')

# %%
min = np.loadtxt('mshIndep/40w.xy')
mid = np.loadtxt('mshIndep/142w.xy')
max = np.loadtxt('mshIndep/274w.xy')

plt.scatter((min[:,0]-100)/10.8,min[:,1],marker='+',c='b',label='0.39m')
plt.scatter((mid[:,0]-100)/10.8,mid[:,1],marker='o',c='none',edgecolors='r',label='1.42m')
plt.scatter((max[:,0]-100)/10.8,max[:,1],marker='^',c='none',edgecolors='k',label='2.74m')

# plt.grid(linestyle='--')
plt.legend(fontsize=16,loc='lower right')
plt.xlabel('Distance(x/D)',fontsize=20)
#plt.ylabel('Pressure Gradient('r'$\frac{\Delta P}{\Delta L}$'')',fontsize=14)
plt.ylabel('Relative Velocity(u$_x$ / U$_{IN}$)',fontsize=20)

plt.tick_params(top=True,right=True)
# plt.rcParams['ytick.direction']='in'
# plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
axes.minorticks_on()
plt.tick_params(which='major',length=6)

x = [-0.5,-0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')
x = [0.5,0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')

plt.xlim([-5,9.5])
plt.ylim([-0.4,1.2])
# Out:
# (-0.4, 1.2)

# %%
###############################################################
## SVF=0.2
UmtNew = np.loadtxt('UM/multicy/graphUniform/300/line_1.xy')
vNew = (UmtNew[:,0]-110)/10
vrmsdata = np.sqrt(pow(UmtNew[:,2],2))

plt.plot(vNew,vrmsdata,marker='+',c='k',label='Presnet work')

# ###########################################################
