# %%
import numpy as np
import matplotlib.pylab as plt
plt.rc('font',family='Times New Roman')

inU = np.loadtxt('PC/porousCylinder/InU/0/surfaceFieldValue.dat',skiprows=4)
inP = np.loadtxt('PC/porousCylinder/InP/0/surfaceFieldValue.dat',skiprows=4)
outP = np.loadtxt('PC/porousCylinder/OutP/0/surfaceFieldValue.dat',skiprows=4)
dp = inP[:,1]-outP[:,1]
print(dp)

# plt.plot(inU[:,0],inU[:,1],label='U')
plt.plot(inP[:,0],inP[:,1],linestyle='--',c='b',label='RANS_inP')
plt.plot(outP[:,0],outP[:,1],linestyle='-.',c='r',label='RANS_outp')
plt.plot(outP[:,0],dp,c='k',label='RANS_dp',linestyle='--')
plt.xlim([0,300])

dpa = np.average(dp[237:312])
print(dpa)

##############################################

# inU = np.loadtxt('../porousCylinder/postProcessing/I/0/surfaceFieldValue.dat',skiprows=4)
inP = np.loadtxt('PC/multicylinder/inP_faceZoneAverage/0/surfaceFieldValue.dat',skiprows=4)
outP = np.loadtxt('PC/multicylinder/outP_faceZoneAverage/0/surfaceFieldValue.dat',skiprows=4)
dp = inP[:,1]-outP[:,1]
# print(dp)

# plt.plot(inU[:,0],inU[:,1],label='U')
plt.plot(inP[:,0],inP[:,1],linestyle='-',c='b',label='LES_inP')
plt.plot(outP[:,0],outP[:,1],linestyle='-',c='r',label='LES_outp')
plt.plot(outP[:,0],dp,c='k',label='LES_dp',linestyle='-')

################################################
plt.legend()
plt.grid(linestyle='--')
plt.legend(fontsize=10)
plt.xlabel('Time',fontsize=12)
plt.ylabel('Pressure',fontsize=12)

##############################################
# Out:
# [0.        0.        0.        ... 0.3719244 0.3719244 0.3719236]
# 0.4285715359999999
# Text(0, 0.5, 'Pressure')

# %%
fig = plt.figure()
fig.set_size_inches(10,6)

#####################################
plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
axes.minorticks_on()
# plt.tick_params(which='major',width=2)
plt.tick_params(which='major',length=6)
# plt.tick_params(which='minor',width=2)
# plt.tick_params(which='minor',length=3)
#####################################

v = np.loadtxt('PC/porousCylinder/graphUniform/300/line.xy',skiprows=1)
v1 = (v[:,0]-100)/10.8
plt.scatter(v1,v[:,1],color='k',marker='o',label='porousCylidner_Ux')
# plt.scatter(v[:,0],v[:,2],linewidths=0.1,marker='*')
# plt.scatter(v[:,0],v[:,3],linewidths=0.1,marker='*')
v = np.loadtxt('PC/multicylinder/graphUniform/300/line_1.xy',skiprows=1)
v1 = (v[:,0]-100)/10.8
plt.scatter(v1,v[:,1],color='r',marker='v',label='multiCylidner_Ux')
# plt.scatter(v[:,0],v[:,2],linewidths=0.1,marker='*')
# plt.scatter(v[:,0],v[:,3],linewidths=0.1,marker='*')

# #######################################################
# chang = np.loadtxt('UM/Chang,2021,SVF=0.2(3D).csv')
# changd = chang[:,0]-0.9
# plt.scatter(changd,chang[:,1])
# #######################################################

plt.xlim([-5,9])
# plt.ylim([-0.4,1.2])

#########################################################
v = np.loadtxt('PC/porousCylinder/graphUniform/300/line.xy',skiprows=1)
v1 = (v[:,0]-100)/10.8

# plt.scatter(v[:,0],v[:,1],linewidths=0.1,marker='*')
plt.plot(v1,v[:,2],c='k',label='porousCylidner_Uy')

plt.plot(v1,v[:,3],c='r',label='porousCylidner_Uz')
v = np.loadtxt('PC/multicylinder/graphUniform/300/line_1.xy',skiprows=1)
v1 = (v[:,0]-100)/10.8
# plt.scatter(v[:,0],v[:,1],linewidths=0.1,marker='*')
plt.plot(v1,v[:,2],linestyle='--',c='k',label='multiCylidner_Uy')
plt.plot(v1,v[:,3],linestyle='--',c='r',label='multiCylidner_Uz')
#############################################################

# plt.grid(linestyle='--')
plt.legend(fontsize=14,loc='center left')
plt.xlabel('Distance(x/D)',fontsize=16)
plt.ylabel('Relative Velocity(u / U$_{IN}$)',fontsize=16)

x = [-0.5,-0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')
x = [0.5,0.5]
y = [-0.4,1.2]
plt.plot(x,y,linestyle = '--',c='g')

plt.xlim([-5,9.5])
plt.ylim([-0.4,1.2])

plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'

# %%
v = np.loadtxt('PC/porousCylinder/graphUniform/300/line.xy',skiprows=1)
v1 = (v[:,0]-110)/10

#####################################
plt.tick_params(top=True,right=True)
plt.rcParams['ytick.direction']='in'
plt.rcParams['xtick.direction']='in'
plt.tick_params(labelsize=16)
axes=plt.subplot()
axes.minorticks_on()
# plt.tick_params(which='major',width=2)
plt.tick_params(which='major',length=6)
# plt.tick_params(which='minor',width=2)
# plt.tick_params(which='minor',length=3)
#####################################

# plt.scatter(v[:,0],v[:,1],linewidths=0.1,marker='*')
plt.plot(v1,v[:,2],c='b',label='porousCylidner_Uy')
plt.plot(v1,v[:,3],c='r',label='porousCylidner_Uz')
v = np.loadtxt('PC/multicylinder/graphUniform/300/line_1.xy',skiprows=1)
v1 = (v[:,0]-110)/10
# plt.scatter(v[:,0],v[:,1],linewidths=0.1,marker='*')
plt.plot(v1,v[:,2],linestyle='--',c='b',label='multiCylidner_Uy')
plt.plot(v1,v[:,3],linestyle='--',c='r',label='multiCylidner_Uz')

plt.xlim([0,9])
plt.grid(linestyle='--')
# plt.legend(fontsize=10)
plt.xlabel('Distance(x/D)',fontsize=16)
plt.ylabel('Relative Velocity(U / U$_{IN}$)',fontsize=16)
# Out:
# Text(0, 0.5, 'Relative Velocity(U / U$_{IN}$)')
